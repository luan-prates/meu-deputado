# %%
#!pip install tabula-py
# Out:
# Requirement already satisfied: tabula-py in c:\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (from tabula-py) (0.25.1)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from tabula-py) (1.16.5)
# Requirement already satisfied: distro in c:\anaconda3\lib\site-packages (from tabula-py) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\anaconda3\lib\site-packages (from pandas->tabula-py) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\anaconda3\lib\site-packages (from pandas->tabula-py) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->tabula-py) (1.12.0)

# %%
from tabula import read_pdf
import pandas as pd

# %%
deputados_mes = [
    ['Janeiro', '01',
        ['ADERLANIA NORONHA', 'AGENOR NETO', 'ANTONIO GRANJA', 'AUDIC MOTA', 'AUGUSTA BRITO', 'BETHROSE',
         'BRUNO GONCALVES', 'BRUNO PEDROSA', 'CAPITAO WAGNER', 'CARLOS FELIPE', 'CARLOS MATOS', 'DANNIEL OLIVEIRA',
         'DAVID DURAND', 'DEDE TEIXEIRA', 'DR. SARTO', 'DRA SILVANA', 'ELMANO', 'ELY AGUIAR', 'EVANDRO LEITAO',
         'FERNANDA PESSOA', 'FERNANDO HUGO', 'FERREIRA ARAGAO', 'GONY ARRUDA', 'HEITOR FERRER', 'JEOVA MOTA',
         'JOAO JAIME', 'JOAQUIM NORONHA', 'JOSE ALBUQUERQUE', 'JULINHO', 'LEONARDO ARAUJO', 'LEONARDO PINHEIRO',
         'LUCILVIO GIRAO', 'MANOEL DUCA', 'MARIO HELIO', 'MIRIAN SOBREIRA', 'MOISES BRAZ', 'ODILON AGUIAR',
         'OSMAR BAQUIT', 'RACHEL MARQUES', 'RENATO ROSENO', 'ROBERIO MONTEIRO', 'ROBERTO MESQUITA', 'SERGIO AGUIAR',
         'TIN GOMES', 'TOMAZ HOLANDA', 'WALTER CAVALCANTE']],
    ['Fevereiro', '02',
        ['ACRÍSIO SENA', 'ADERLANIA NORONHA', 'AGENOR NETO', 'ANDRE FERNANDES', 'ANTONIO GRANJA',
          'AP. LUIZ HENRIQUE', 'AUDIC MOTA', 'AUGUSTA BRITO', 'BETHROSE', 'BRUNO GONCALVES',
          'BRUNO PEDROSA', 'CAPITAO WAGNER', 'CARLOS FELIPE', 'CARLOS MATOS', 'DANNIEL OLIVEIRA',
          'DAVID DURAND', 'DEDE TEIXEIRA', 'DELEGADO CAVALCANTE', 'DR. SARTO', 'DRA SILVANA', 'ELMANO',
          'ELY AGUIAR', 'ERIKA AMORIM', 'EVANDRO LEITAO', 'FERNANDA PESSOA', 'FERNANDO HUGO',
          'FERNANDO SANTANA', 'FERREIRA ARAGAO', 'GONY ARRUDA', 'GUILHERME LANDIM', 'HEITOR FERRER',
          'JEOVA MOTA', 'JOAO JAIME', 'JOSE ALBUQUERQUE', 'JULINHO', 'LEONARDO ARAUJO', 'LEONARDO PINHEIRO',
          'LUCILVIO GIRAO', 'MANOEL DUCA', 'MARCOS SOBREIRA', 'MARIO HELIO', 'MIRIAN SOBREIRA',
          'MOISES BRAZ', 'NELINHO', 'NEZINHO FARIAS', 'NIZO COSTA', 'ODILON AGUIAR', 'OSMAR BAQUIT',
          'PATRICIA AGUIAR', 'QUEIROZ FILHO', 'RACHEL MARQUES', 'RENATO ROSENO', 'ROBERIO MONTEIRO',
          'ROMEU ALDIGUERI', 'SERGIO AGUIAR', 'SOLDADO NOELIO', 'TIN GOMES', 'TOMAZ HOLANDA', 'VITOR VALIM',
          'WALTER CAVALCANTE']],
    ['Março', '03',
         ['ACRÍSIO SENA', 'ADERLANIA NORONHA', 'AGENOR NETO', 'ANDRE FERNANDES', 'ANTONIO GRANJA', 'AP. LUIZ HENRIQUE',
          'AUDIC MOTA', 'AUGUSTA BRITO', 'BRUNO GONCALVES', 'BRUNO PEDROSA', 'CARLOS FELIPE', 'DANNIEL OLIVEIRA',
          'DAVID DURAND', 'DELEGADO CAVALCANTE', 'DR. SARTO', 'DRA SILVANA', 'ELMANO', 'ERIKA AMORIM', 'EVANDRO LEITAO',
          'FERNANDA PESSOA', 'FERNANDO HUGO', 'FERNANDO SANTANA', 'GONY ARRUDA', 'GUILHERME LANDIM', 'HEITOR FERRER',
          'JEOVA MOTA', 'JOAO JAIME', 'JOSE ALBUQUERQUE', 'JULINHO', 'LEONARDO ARAUJO', 'LEONARDO PINHEIRO',
          'LUCILVIO GIRAO', 'MANOEL DUCA', 'MARCOS SOBREIRA', 'MIRIAN SOBREIRA', 'MOISES BRAZ', 'NELINHO', 'NEZINHO FARIAS',
          'NIZO COSTA', 'ODILON AGUIAR', 'OSMAR BAQUIT', 'PATRICIA AGUIAR', 'QUEIROZ FILHO', 'RENATO ROSENO',
          'ROBERIO MONTEIRO', 'ROMEU ALDIGUERI', 'SERGIO AGUIAR', 'SOLDADO NOELIO', 'TIN GOMES', 'VITOR VALIM',
          'WALTER CAVALCANTE']],
    ['Abril', '04',
        ['ACRÍSIO SENA', 'ADERLANIA NORONHA', 'AGENOR NETO', 'ANDRE FERNANDES', 'ANTONIO GRANJA', 'AP. LUIZ HENRIQUE',
         'AUDIC MOTA', 'AUGUSTA BRITO', 'BRUNO GONCALVES', 'BRUNO PEDROSA', 'CARLOS FELIPE', 'DANNIEL OLIVEIRA',
         'DAVID DURAND', 'DELEGADO CAVALCANTE', 'DR. SARTO', 'DRA SILVANA', 'ELMANO', 'ERIKA AMORIM', 'EVANDRO LEITAO',
         'FERNANDA PESSOA', 'FERNANDO HUGO', 'FERNANDO SANTANA', 'GUILHERME LANDIM', 'HEITOR FERRER', 'JEOVA MOTA',
         'JOAO JAIME', 'JÚLIOCÉSAR FILHO', 'LEONARDO ARAUJO', 'LEONARDO PINHEIRO', 'LUCILVIO GIRAO', 'MANOEL DUCA',
         'MARCOS SOBREIRA', 'MOISES BRAZ', 'NELINHO', 'NEZINHO FARIAS', 'NIZO COSTA', 'OSMAR BAQUIT', 'PATRICIA AGUIAR',
         'QUEIROZ FILHO', 'RENATO ROSENO', 'ROBERIO MONTEIRO', 'ROMEU ALDIGUERI', 'SALMITO', 'SERGIO AGUIAR',
         'SOLDADO NOELIO', 'TIN GOMES', 'VITOR VALIM', 'WALTER CAVALCANTE']]
]

# %%
tabela = read_pdf(f"PDFs/2019/Janeiro/ADERLANIA NORONHA.pdf", pages='all')

# %%
df = pd.DataFrame(tabela[0])

# %%
df['Mes'] = 'Janeiro'

# %%
erros = []
df_geral = pd.DataFrame()
for mes in deputados_mes:
    str_mes = mes[0]
    num_mes = mes[1]
    deputados = mes[2]
    for deputado in deputados:
        tabela = read_pdf(f"PDFs/2019/{str_mes}/{deputado}.pdf", pages='all')
        if len(tabela) != 0:
            df = pd.DataFrame(tabela[0])
            df = df.drop(df.index[-1])
            df = df.pivot(columns='Descrição', values='Valor')
            df['Deputado'] = deputado
            df['Data'] = f'01/{num_mes}/2019'

            #print(df.head())
            df_geral = pd.concat([df_geral, df])
            print(df_geral.head())
        else:
            erros.append([str_mes, deputado])
            print(f'Deu Problema em {str_mes} do deputado {deputado}')
# Out:
# Descrição Combustíveis e Lubrificantes Automotivos  \
# 0                                         6.000,00
# 1                                              NaN
#
# Descrição Vale-Refeição e Vale-Alimentação           Deputado        Data
# 0                                      NaN  ADERLANIA NORONHA  01/01/2019
# 1                                 5.000,00  ADERLANIA NORONHA  01/01/2019
# Deu Problema em Janeiro do deputado AGENOR NETO
# Deu Problema em Janeiro do deputado ANTONIO GRANJA
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#   Combustíveis e Lubrificantes Automotivos        Data           Deputado  \
# 0                                 6.000,00  01/01/2019  ADERLANIA NORONHA
# 1                                      NaN  01/01/2019  ADERLANIA NORONHA
# 0                                 6.000,00  01/01/2019         AUDIC MOTA
# 1                                      NaN  01/01/2019         AUDIC MOTA
# 2                                      NaN  01/01/2019         AUDIC MOTA
#
#   Divulgação das Atividades Parlamentares Seguros em Geral  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 0                                     NaN              NaN
# 1                                4.100,00              NaN
# 2                                     NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
# Deu Problema em Janeiro do deputado AUGUSTA BRITO
# Deu Problema em Janeiro do deputado BETHROSE
#   Combustíveis e Lubrificantes Automotivos        Data           Deputado  \
# 0                                 6.000,00  01/01/2019  ADERLANIA NORONHA
# 1                                      NaN  01/01/2019  ADERLANIA NORONHA
# 0                                 6.000,00  01/01/2019         AUDIC MOTA
# 1                                      NaN  01/01/2019         AUDIC MOTA
# 2                                      NaN  01/01/2019         AUDIC MOTA
#
#   Divulgação das Atividades Parlamentares Seguros em Geral  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 0                                     NaN              NaN
# 1                                4.100,00              NaN
# 2                                     NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#   Combustíveis e Lubrificantes Automotivos        Data           Deputado  \
# 0                                 6.000,00  01/01/2019  ADERLANIA NORONHA
# 1                                      NaN  01/01/2019  ADERLANIA NORONHA
# 0                                 6.000,00  01/01/2019         AUDIC MOTA
# 1                                      NaN  01/01/2019         AUDIC MOTA
# 2                                      NaN  01/01/2019         AUDIC MOTA
#
#   Divulgação das Atividades Parlamentares Seguros em Geral  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 0                                     NaN              NaN
# 1                                4.100,00              NaN
# 2                                     NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Divulgação das Atividades Parlamentares  \
# 0  01/01/2019  ADERLANIA NORONHA                                     NaN
# 1  01/01/2019  ADERLANIA NORONHA                                     NaN
# 0  01/01/2019         AUDIC MOTA                                     NaN
# 1  01/01/2019         AUDIC MOTA                                4.100,00
# 2  01/01/2019         AUDIC MOTA                                     NaN
#
#   Hospedagens Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0         NaN                                            NaN              NaN
# 1         NaN                                            NaN              NaN
# 0         NaN                                            NaN              NaN
# 1         NaN                                            NaN              NaN
# 2         NaN                                            NaN              NaN
#
#   Seguros em Geral Serviços Gráficos e Editoriais  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2           504,04                            NaN
#
#   Serviços Técnicos Profissionais Serviços de Telecomunicações  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Divulgação das Atividades Parlamentares  \
# 0  01/01/2019  ADERLANIA NORONHA                                     NaN
# 1  01/01/2019  ADERLANIA NORONHA                                     NaN
# 0  01/01/2019         AUDIC MOTA                                     NaN
# 1  01/01/2019         AUDIC MOTA                                4.100,00
# 2  01/01/2019         AUDIC MOTA                                     NaN
#
#   Hospedagens Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0         NaN                                            NaN              NaN
# 1         NaN                                            NaN              NaN
# 0         NaN                                            NaN              NaN
# 1         NaN                                            NaN              NaN
# 2         NaN                                            NaN              NaN
#
#   Seguros em Geral Serviços Gráficos e Editoriais  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2           504,04                            NaN
#
#   Serviços Técnicos Profissionais Serviços de Telecomunicações  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Seguros em Geral Serviços Gráficos e Editoriais  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2           504,04                            NaN
#
#   Serviços Técnicos Profissionais Serviços de Telecomunicações  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
# Deu Problema em Janeiro do deputado DANNIEL OLIVEIRA
# Deu Problema em Janeiro do deputado DAVID DURAND
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Seguros em Geral Serviços Gráficos e Editoriais  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2           504,04                            NaN
#
#   Serviços Técnicos Profissionais Serviços de Telecomunicações  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
# Deu Problema em Janeiro do deputado DR. SARTO
# Deu Problema em Janeiro do deputado DRA SILVANA
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Seguros em Geral Serviços Gráficos e Editoriais  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2           504,04                            NaN
#
#   Serviços Técnicos Profissionais Serviços de Telecomunicações  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
# Deu Problema em Janeiro do deputado ELY AGUIAR
# Deu Problema em Janeiro do deputado EVANDRO LEITAO
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Seguros em Geral Serviços Gráficos e Editoriais  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2           504,04                            NaN
#
#   Serviços Técnicos Profissionais Serviços de Telecomunicações  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
# Deu Problema em Janeiro do deputado FERNANDO HUGO
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# Deu Problema em Janeiro do deputado JEOVA MOTA
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Veículos  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 0                                     NaN         NaN                 NaN
# 1                                4.100,00         NaN                 NaN
# 2                                     NaN         NaN                 NaN
#
#   Outros Serviços de Terceiros - Pessoa Jurídica Passagens Aéreas  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos Outros Serviços de Terceiros - Pessoa Jurídica  \
# 0                 NaN                                            NaN
# 1                 NaN                                            NaN
# 0                 NaN                                            NaN
# 1                 NaN                                            NaN
# 2                 NaN                                            NaN
#
#   Passagens Aéreas Passagens e Despesas com Locomoção Seguros em Geral  \
# 0              NaN                                NaN              NaN
# 1              NaN                                NaN              NaN
# 0              NaN                                NaN              NaN
# 1              NaN                                NaN              NaN
# 2              NaN                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos Outros Serviços de Terceiros - Pessoa Jurídica  \
# 0                 NaN                                            NaN
# 1                 NaN                                            NaN
# 0                 NaN                                            NaN
# 1                 NaN                                            NaN
# 2                 NaN                                            NaN
#
#   Passagens Aéreas Passagens e Despesas com Locomoção Seguros em Geral  \
# 0              NaN                                NaN              NaN
# 1              NaN                                NaN              NaN
# 0              NaN                                NaN              NaN
# 1              NaN                                NaN              NaN
# 2              NaN                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos Outros Serviços de Terceiros - Pessoa Jurídica  \
# 0                 NaN                                            NaN
# 1                 NaN                                            NaN
# 0                 NaN                                            NaN
# 1                 NaN                                            NaN
# 2                 NaN                                            NaN
#
#   Passagens Aéreas Passagens e Despesas com Locomoção Seguros em Geral  \
# 0              NaN                                NaN              NaN
# 1              NaN                                NaN              NaN
# 0              NaN                                NaN              NaN
# 1              NaN                                NaN              NaN
# 2              NaN                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Telecomunicações Vale-Refeição e Vale-Alimentação
# 0                          NaN                              NaN
# 1                          NaN                         5.000,00
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
# ...
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Comunicação em Geral Serviços de Telecomunicações  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#   Serviços de Telecomunicações - Pacote de Dados  \
# 0                                            NaN
# 1                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
# [5 rows x 21 columns]
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos  ... Passagens Aéreas Passagens Terrestres  \
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 2                 NaN  ...              NaN                  NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Comunicação em Geral Serviços de Telecomunicações  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#   Serviços de Telecomunicações - Pacote de Dados  \
# 0                                            NaN
# 1                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
# [5 rows x 21 columns]
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos  ... Passagens Aéreas Passagens Terrestres  \
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 2                 NaN  ...              NaN                  NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Comunicação em Geral Serviços de Telecomunicações  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#   Serviços de Telecomunicações - Pacote de Dados  \
# 0                                            NaN
# 1                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
# [5 rows x 21 columns]
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos  ... Passagens Aéreas Passagens Terrestres  \
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 2                 NaN  ...              NaN                  NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Comunicação em Geral Serviços de Telecomunicações  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#   Serviços de Telecomunicações - Pacote de Dados  \
# 0                                            NaN
# 1                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
# [5 rows x 21 columns]
#   Assinaturas de Periódicos e Anuidades  \
# 0                                   NaN
# 1                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
#   Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 0                                 6.000,00                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
#
#          Data           Deputado Despesas de Teleprocessamento  \
# 0  01/01/2019  ADERLANIA NORONHA                           NaN
# 1  01/01/2019  ADERLANIA NORONHA                           NaN
# 0  01/01/2019         AUDIC MOTA                           NaN
# 1  01/01/2019         AUDIC MOTA                           NaN
# 2  01/01/2019         AUDIC MOTA                           NaN
#
#   Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                     NaN         NaN                  NaN
# 1                                     NaN         NaN                  NaN
# 0                                     NaN         NaN                  NaN
# 1                                4.100,00         NaN                  NaN
# 2                                     NaN         NaN                  NaN
#
#   Locação de Veículos  ... Passagens Aéreas Passagens Terrestres  \
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 0                 NaN  ...              NaN                  NaN
# 1                 NaN  ...              NaN                  NaN
# 2                 NaN  ...              NaN                  NaN
#
#   Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN           504,04
#
#   Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#   Serviços de Comunicação em Geral Serviços de Telecomunicações  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
#
#   Serviços de Telecomunicações - Pacote de Dados  \
# 0                                            NaN
# 1                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#   Vale-Refeição e Vale-Alimentação
# 0                              NaN
# 1                         5.000,00
# 0                              NaN
# 1                              NaN
# 2                              NaN
#
# [5 rows x 21 columns]

# %%
df_geral
# Out:
#    Assinaturas de Periódicos e Anuidades  \
# 0                                    NaN
# 1                                    NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# ..                                   ...
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
#
#    Combustíveis e Lubrificantes Automotivos Convênio com Plano de Saúde  \
# 0                                  6.000,00                         NaN
# 1                                       NaN                         NaN
# 0                                  6.000,00                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# ..                                      ...                         ...
# 7                                       NaN                         NaN
# 8                                       NaN                         NaN
# 9                                       NaN                         NaN
# 10                                      NaN                         NaN
# 11                                      NaN                         NaN
#
#           Data           Deputado Despesas de Teleprocessamento  \
# 0   01/01/2019  ADERLANIA NORONHA                           NaN
# 1   01/01/2019  ADERLANIA NORONHA                           NaN
# 0   01/01/2019         AUDIC MOTA                           NaN
# 1   01/01/2019         AUDIC MOTA                           NaN
# 2   01/01/2019         AUDIC MOTA                           NaN
# ..         ...                ...                           ...
# 7   01/04/2019  WALTER CAVALCANTE                           NaN
# 8   01/04/2019  WALTER CAVALCANTE                           NaN
# 9   01/04/2019  WALTER CAVALCANTE                           NaN
# 10  01/04/2019  WALTER CAVALCANTE                           NaN
# 11  01/04/2019  WALTER CAVALCANTE                           NaN
#
#    Divulgação das Atividades Parlamentares Hospedagens Locação de Aeronaves  \
# 0                                      NaN         NaN                  NaN
# 1                                      NaN         NaN                  NaN
# 0                                      NaN         NaN                  NaN
# 1                                 4.100,00         NaN                  NaN
# 2                                      NaN         NaN                  NaN
# ..                                     ...         ...                  ...
# 7                                      NaN         NaN                  NaN
# 8                                      NaN         NaN                  NaN
# 9                                      NaN         NaN                  NaN
# 10                                     NaN         NaN                  NaN
# 11                                     NaN         NaN                  NaN
#
#    Locação de Veículos  ... Passagens Aéreas Passagens Terrestres  \
# 0                  NaN  ...              NaN                  NaN
# 1                  NaN  ...              NaN                  NaN
# 0                  NaN  ...              NaN                  NaN
# 1                  NaN  ...              NaN                  NaN
# 2                  NaN  ...              NaN                  NaN
# ..                 ...  ...              ...                  ...
# 7                  NaN  ...              NaN                  NaN
# 8                  NaN  ...              NaN                  NaN
# 9                  NaN  ...              NaN                  NaN
# 10                 NaN  ...              NaN                  NaN
# 11                 NaN  ...              NaN                  NaN
#
#    Passagens e Despesas com Locomoção Seguros em Geral  \
# 0                                 NaN              NaN
# 1                                 NaN              NaN
# 0                                 NaN              NaN
# 1                                 NaN              NaN
# 2                                 NaN           504,04
# ..                                ...              ...
# 7                                 NaN         1.453,18
# 8                                 NaN              NaN
# 9                                 NaN              NaN
# 10                                NaN              NaN
# 11                                NaN              NaN
#
#    Serviços Gráficos e Editoriais Serviços Técnicos Profissionais  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# ..                            ...                             ...
# 7                             NaN                             NaN
# 8                             NaN                        3.960,00
# 9                             NaN                             NaN
# 10                            NaN                             NaN
# 11                            NaN                             NaN
#
#    Serviços de Comunicação em Geral Serviços de Telecomunicações  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# ..                              ...                          ...
# 7                               NaN                          NaN
# 8                               NaN                          NaN
# 9                          2.087,79                          NaN
# 10                              NaN                          NaN
# 11                              NaN                          NaN
#
#    Serviços de Telecomunicações - Pacote de Dados  \
# 0                                             NaN
# 1                                             NaN
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# ..                                            ...
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                         292,53
# 11                                            NaN
#
#    Vale-Refeição e Vale-Alimentação
# 0                               NaN
# 1                          5.000,00
# 0                               NaN
# 1                               NaN
# 2                               NaN
# ..                              ...
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11                         4.000,00
#
# [876 rows x 21 columns]

# %%
df_geral.reset_index(inplace=True)
df_geral.drop('index', axis=1)
df_geral.to_csv('gastos_candidatos.csv')

# %%
df_geral.drop('index', axis=1)
# Out:
#      index                                       Descrição     Valor  \
# 0        0        Combustíveis e Lubrificantes Automotivos  6.000,00
# 1        1                Vale-Refeição e Vale-Alimentação  5.000,00
# 2        0        Combustíveis e Lubrificantes Automotivos  6.000,00
# 3        1         Divulgação das Atividades Parlamentares  4.100,00
# 4        2                                Seguros em Geral    504,04
# ..     ...                                             ...       ...
# 871      7                                Seguros em Geral  1.453,18
# 872      8                 Serviços Técnicos Profissionais  3.960,00
# 873      9                Serviços de Comunicação em Geral  2.087,79
# 874     10  Serviços de Telecomunicações - Pacote de Dados    292,53
# 875     11                Vale-Refeição e Vale-Alimentação  4.000,00
#
#               Deputado        Data
# 0    ADERLANIA NORONHA  01/01/2019
# 1    ADERLANIA NORONHA  01/01/2019
# 2           AUDIC MOTA  01/01/2019
# 3           AUDIC MOTA  01/01/2019
# 4           AUDIC MOTA  01/01/2019
# ..                 ...         ...
# 871  WALTER CAVALCANTE  01/04/2019
# 872  WALTER CAVALCANTE  01/04/2019
# 873  WALTER CAVALCANTE  01/04/2019
# 874  WALTER CAVALCANTE  01/04/2019
# 875  WALTER CAVALCANTE  01/04/2019
#
# [876 rows x 5 columns]

# %%
#df_geral.pivot(index = 'Deputado', columns ='Descrição', values=['Valor', 'Data'])
